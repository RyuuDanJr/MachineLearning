# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
# 28x28 images of hand written digits 0-9
mnist= tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test)= mnist.load_data()
## Normalize Pixel Data

x_train= tf.keras.utils.normalize(x_train, axis=1)
x_test= tf.keras.utils.normalize(x_test, axis=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(x_train[0])
plt.show()

# %%
model= tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation= tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation= tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation= tf.nn.softmax))

model.compile(optimizer= 'adam', loss= 'sparse_categorical_crossentropy',
              metrics= ['accuracy'])
model.fit(x_train, y_train, epochs= 3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 19s 8ms/step - loss: 0.2620 - accuracy: 0.9242
# Epoch 2/3
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1061 - accuracy: 0.9677
# Epoch 3/3
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0721 - accuracy: 0.9773

# %%
val_loss, val_acc= model.evaluate(x_test, y_test)
print(f'The val_loss is {val_loss} and the val_acc is {val_acc}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1001 - accuracy: 0.9694
# The val_loss is 0.10005569458007812 and the val_acc is 0.9693999886512756

# %%
from random import randint
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler

# %%
train_labels= []
train_samples= []

# %% [markdown]
#   Example Data:
#
#
# *   An experimental drug was tested on individuals from ages 13 to 100 in a clincal trial
# *   The trial had 2100 participants. Half were under 65 years old, half were 65 years or older
# * Around 95% of patients 65 or older experienced side effects
# * Around 95% of patients under 65 experienced no side effects
